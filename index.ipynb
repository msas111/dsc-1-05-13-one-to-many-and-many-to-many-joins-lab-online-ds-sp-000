# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()
empoffice = pd.DataFrame(cur.execute("""select * from employees join offices using(officeCode);""").fetchall())
empoffice.head()
empoffice2 = cur.execute("""select * from employees join offices using(officeCode);""")
cur.execute('''SELECT * FROM employees ORDER BY firstName;''').fetchall()
cur.execute('''SELECT * FROM employees ORDER BY lastName;''').fetchall()

#Your code here
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# [('1102',
#   'Bondur',
#   'Gerard',
#   'x5408',
#   'gbondur@classicmodelcars.com',
#   '4',
#   '1056',
#   'Sale Manager (EMEA)'),
#  ('1337',
#   'Bondur',
#   'Loui',
#   'x6493',
#   'lbondur@classicmodelcars.com',
#   '4',
#   '1102',
#   'Sales Rep'),
#  ('1501',
#   'Bott',
#   'Larry',
#   'x2311',
#   'lbott@classicmodelcars.com',
#   '7',
#   '1102',
#   'Sales Rep'),
#  ('1143',
#   'Bow',
#   'Anthony',
#   'x5428',
#   'abow@classicmodelcars.com',
#   '1',
#   '1056',
#   'Sales Manager (NA)'),
#  ('1401',
#   'Castillo',
#   'Pamela',
#   'x2759',
#   'pcastillo@classicmodelcars.com',
#   '4',
#   '1102',
# ...

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
cur.execute('''SELECT * FROM customers;''').fetchall()
df2 = pd.DataFrame(cur.execute("""select * from orders join customers using(customerNumber);""").fetchall())
df2.columns = [i[0] for i in cur.description]
print('Number of results:', len(df2))
df2.head()
# Your code here
# Out:
# Number of results: 326
#   orderNumber   orderDate requiredDate shippedDate   status  \
# 0       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1       10101  2003-01-09   2003-01-18  2003-01-11  Shipped
# 2       10102  2003-01-10   2003-01-18  2003-01-14  Shipped
# 3       10103  2003-01-29   2003-02-07  2003-02-02  Shipped
# 4       10104  2003-01-31   2003-02-09  2003-02-01  Shipped
#
#                  comments customerNumber                  customerName  \
# 0                                    363  Online Diecast Creations Co.
# 1  Check on availability.            128          Blauer See Auto, Co.
# 2                                    181               Vitachrome Inc.
# 3                                    121            Baane Mini Imports
# 4                                    141        Euro+ Shopping Channel
#
#   contactLastName contactFirstName              phone  \
# 0           Young          Dorothy         6035558647
# ...

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
df3 = pd.DataFrame(cur.execute("""select * from orders join orderdetails using(orderNumber);""").fetchall())
df3.columns = [i[0] for i in cur.description]
print('Number of results:', len(df3))
df3.head()
# Your code here
# Out:
# Number of results: 2996
#   orderNumber   orderDate requiredDate shippedDate   status  \
# 0       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 2       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 3       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 4       10101  2003-01-09   2003-01-18  2003-01-11  Shipped
#
#                  comments customerNumber productCode quantityOrdered  \
# 0                                    363    S18_1749              30
# 1                                    363    S18_2248              50
# 2                                    363    S18_4409              22
# 3                                    363    S24_3969              49
# 4  Check on availability.            128    S18_2325              25
#
#   priceEach orderLineNumber
# 0    136.00               3
# 1     55.09               2
# 2     75.46               4
# 3     35.29               1
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and allthe product information for each product in the order.

# %%
df4 = pd.DataFrame(cur.execute("""select * from orders join orderdetails using(orderNumber) join products using (productCode);""").fetchall())
df4.head()
df4.columns = [i[0] for i in cur.description]
print('Number of results:', len(df4))
df4.head()
# Your code here
# Out:
# Number of results: 2996
#   orderNumber   orderDate requiredDate shippedDate   status  \
# 0       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 2       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 3       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 4       10101  2003-01-09   2003-01-18  2003-01-11  Shipped
#
#                  comments customerNumber productCode quantityOrdered  \
# 0                                    363    S18_1749              30
# 1                                    363    S18_2248              50
# 2                                    363    S18_4409              22
# 3                                    363    S24_3969              49
# 4  Check on availability.            128    S18_2325              25
#
#   priceEach orderLineNumber                          productName  \
# 0    136.00               3             1917 Grand Touring Sedan
# ...

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
